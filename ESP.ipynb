# %% [markdown]
# Employe Salary Prediction

# %%
import pandas as pd
df = pd.read_csv("/content/employee_attrition_data.csv")
print(df.head())
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
print(df.head(10))
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
# 5            0.889018                    237                      0   97212
# 6            0.688977                    155                      1   97865
# 7            0.981679                    171                      0   50113
# 8            0.010381                    177                      1   88747
# 9            0.466782                    170                      0   43283
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          0

# %%
print(df.columns)
df.info
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')
# <bound method DataFrame.info of      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]>

# %%
df.isna()
df.isna().sum()
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
# Replace 'column1', 'column2', etc. with the actual column names you want to drop
df = df.drop(['Employee_ID'], axis=1)
print(df.head())
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
#df.drop(axis=1, columns=['Employee_ID'])
print(df.head())
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

df["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender Count of employee")
plt.show()

# %%
import matplotlib.pyplot as plt

df["Age"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Age Count of employee")
plt.show()

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.title("Average Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary")
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
df.describe()
# Out:
#                Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000       1000.000000         1000.000000
# mean     42.205000          5.605000            0.505995
# std      10.016452          2.822223            0.289797
# min      25.000000          1.000000            0.001376
# 25%      33.000000          3.000000            0.258866
# 50%      43.000000          6.000000            0.505675
# 75%      51.000000          8.000000            0.761135
# max      59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# min               150.000000               0.000000  30099.000000     0.000000
# 25%               173.000000               0.000000  47613.500000     0.000000
# 50%               201.000000               0.000000  64525.000000     0.000000
# 75%               225.000000               1.000000  81921.000000     1.000000
# max               249.000000               1.000000  99991.000000     1.000000

# %%
x = df[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y = df["Salary"]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.84537988,  0.05434645, -0.23822491],
#        [ 1.20264555, -1.37662572,  1.17248307],
#        [ 1.55991122,  1.114404  , -1.54816805],
#        ...,
#        [ 1.55991122, -0.2394277 ,  1.3404245 ],
#        [-0.22641712,  0.15752577,  1.60913078],
#        [ 1.55991122, -0.59214197, -1.14510862]])

# %%
import joblib
joblib.dump(sc,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = sc.transform(X_test)

# %%
X_test
# Out:
# array([[-1.29821412, -0.62015237, -0.7420492 ],
#        [-0.22641712, -0.28158018,  1.5755425 ],
#        [-1.65547978, -1.2910015 ,  0.03048137],
#        [-0.58368278,  0.86283734,  1.3404245 ],
#        [ 0.48811422,  1.57268757, -0.43975463],
#        [ 0.84537988, -0.58804975, -1.44740319],
#        [-1.65547978, -0.62740641, -0.20463663],
#        [ 1.55991122,  0.59676726,  0.33277594],
#        [ 0.84537988,  0.50915824, -1.27946176],
#        [ 0.48811422,  1.50229119,  0.09765794],
#        [-0.58368278,  1.31525978, -0.2718132 ],
#        [-0.94094845,  1.6386259 , -0.23822491],
#        [ 1.20264555,  1.28506336, -0.37257806],
#        [ 0.48811422, -0.74186844,  1.40760107],
#        [ 1.20264555,  0.24482431,  0.50071736],
#        [-0.22641712, -1.34748034, -0.13746006],
#        [ 0.48811422, -1.20603398,  0.63507051],
#        [-0.94094845,  0.98217028,  0.56789394],
#        [-1.29821412,  0.74239169, -0.87640234],
#        [ 0.13084855,  1.2831224 ,  1.30683621],
#        [ 1.20264555, -1.42279205, -0.80922577],
#        [ 0.13084855, -0.31126084,  0.97095336],
#        [-0.94094845, -1.38670678, -0.10387177],
#        [-1.29821412,  1.52090464, -0.70846091],
#        [ 1.55991122, -0.83388724,  0.8701885 ],
#        [-1.29821412, -1.00157515,  0.70224708],
#        [-1.65547978,  0.01245246,  0.80301193],
#        [-1.65547978,  1.02467895,  0.50071736],
#        [-0.58368278, -0.1042989 , -1.48099147],
#        [-0.94094845, -0.36713758, -0.64128434],
#        [-0.94094845, -0.59590388,  0.13124623],
#        [-1.65547978,  1.1665698 ,  1.67630735],
#        [ 1.55991122, -0.99446605, -0.94357891],
#        [ 1.20264555,  0.2903005 , -1.61534462],
#        [-1.29821412,  1.18849235, -1.48099147],
#        [ 0.84537988, -0.43617586,  0.60148222],
#        [-1.29821412,  0.90708453, -0.64128434],
#        [ 0.48811422, -0.99872556,  1.67630735],
#        [ 0.48811422, -1.16995158, -0.0366952 ],
#        [-1.65547978, -0.50875182,  0.1984228 ],
#        [-0.22641712, -0.63068448,  1.00454165],
#        [-1.65547978,  0.86776575,  1.44118936],
#        [ 0.48811422,  1.51201824,  0.39995251],
#        [ 0.84537988, -1.49290566,  1.5755425 ],
#        [ 0.84537988,  1.09495948,  0.63507051],
#        [ 1.20264555,  0.35448911, -0.40616634],
#        [-1.65547978,  1.43271218,  1.67630735],
#        [ 1.20264555,  0.49119843,  0.13124623],
#        [-1.29821412,  1.00223371,  0.26559937],
#        [ 0.84537988, -0.60047049, -0.87640234],
#        [ 0.84537988, -1.41491531, -0.23822491],
#        [ 1.55991122,  1.6186631 , -1.14510862],
#        [-0.94094845,  1.31598155,  1.54195421],
#        [ 0.84537988,  0.03859959, -0.17104834],
#        [-1.29821412,  1.16634698,  1.17248307],
#        [-0.58368278, -1.68636948, -1.61534462],
#        [-1.65547978, -1.12541503,  0.09765794],
#        [ 1.20264555, -1.60038501, -0.87640234],
#        [ 0.13084855,  1.21919763, -0.5069312 ],
#        [-1.65547978, -0.11947258, -0.43975463],
#        [-1.65547978,  1.34481382,  0.36636422],
#        [ 1.20264555,  1.68293473,  1.30683621],
#        [ 0.84537988,  0.36074708, -1.31305005],
#        [ 0.48811422,  1.33967282, -0.5069312 ],
#        [ 1.20264555,  0.0484133 , -0.54051948],
#        [ 1.55991122, -0.08325461,  0.1984228 ],
#        [ 0.48811422, -1.65793507,  1.40760107],
#        [ 0.13084855, -1.55875796, -0.17104834],
#        [ 0.48811422, -0.1230203 , -0.97716719],
#        [ 0.84537988,  1.55768841, -1.6489329 ],
#        [-0.58368278, -0.06557682, -0.00310692],
#        [-1.65547978, -0.47205753, -1.01075548],
#        [ 1.55991122, -0.83439901,  0.73583536],
#        [ 1.20264555, -0.16947237,  0.13124623],
#        [ 0.84537988,  0.99116091, -1.61534462],
#        [-1.65547978,  1.44733955, -1.61534462],
#        [ 1.55991122, -0.84774776, -0.54051948],
#        [ 0.48811422,  1.67233894, -1.17869691],
#        [ 0.84537988,  0.43962213,  0.66865879],
#        [-0.94094845, -0.03272995,  0.83660022],
#        [-0.22641712,  0.64569436, -1.48099147],
#        [ 0.13084855, -1.05829689,  0.80301193],
#        [-1.65547978, -0.04243226,  1.27324793],
#        [ 0.84537988, -1.44482665,  0.26559937],
#        [ 1.20264555,  0.54475587,  1.64271907],
#        [-0.58368278,  1.65900153,  0.23201108],
#        [-1.65547978, -0.69501229,  0.60148222],
#        [-0.58368278,  0.14613967, -0.43975463],
#        [ 1.20264555,  1.40466172, -1.21228519],
#        [ 0.48811422,  0.42334216,  0.53430565],
#        [ 0.84537988,  0.42069613,  1.27324793],
#        [-0.94094845,  1.61338871,  1.1053065 ],
#        [ 0.13084855, -0.08035794, -1.11152033],
#        [-0.22641712, -1.70691408,  1.64271907],
#        [ 1.20264555,  1.24676067,  0.97095336],
#        [ 1.20264555,  0.60469931, -1.61534462],
#        [ 0.48811422, -1.73162722, -0.57410777],
#        [ 1.55991122,  1.34683619, -0.60769605],
#        [-1.29821412, -0.23477169,  0.33277594],
#        [-1.65547978, -0.21767622,  1.44118936],
#        [-1.29821412, -0.37322593,  1.00454165],
#        [-0.58368278, -0.04322723, -1.04434376],
#        [ 0.84537988,  1.25305292, -0.43975463],
#        [ 0.84537988, -0.09234625,  0.80301193],
#        [-0.58368278,  1.48530242,  1.50836593],
#        [ 1.55991122, -0.57224041,  0.23201108],
#        [-0.22641712,  0.39686288,  0.1984228 ],
#        [-1.65547978, -1.54035223, -1.48099147],
#        [-1.65547978, -0.24451583, -0.70846091],
#        [-0.58368278, -1.17943077,  1.44118936],
#        [-1.65547978, -0.24628848, -1.51457976],
#        [-1.65547978,  0.41086557,  0.56789394],
#        [ 1.55991122, -0.94793494,  0.46712908],
#        [-1.29821412, -0.09299707,  1.00454165],
#        [ 1.55991122, -0.96295592,  0.23201108],
#        [-0.22641712, -0.48336826, -0.70846091],
#        [-0.94094845, -0.07203145, -1.54816805],
#        [ 1.55991122, -0.62027598, -0.30540149],
#        [ 0.48811422,  0.9194148 ,  1.5755425 ],
#        [ 1.55991122,  0.06581453, -1.48099147],
#        [-0.22641712,  0.76326428, -0.17104834],
#        [-0.94094845,  1.04241213, -0.80922577],
#        [-0.22641712,  0.25763547, -0.5069312 ],
#        [-1.29821412,  1.56453208,  0.46712908],
#        [-1.29821412, -0.51139433, -0.80922577],
#        [-1.29821412,  1.13727167, -0.13746006],
#        [-0.58368278,  0.30065293,  0.53430565],
#        [ 1.55991122,  0.45080254,  0.09765794],
#        [ 0.84537988, -1.26982233,  1.20607136],
#        [-0.94094845,  0.3890091 , -0.17104834],
#        [-1.29821412, -0.27183862, -0.80922577],
#        [-0.58368278,  1.02337848, -1.04434376],
#        [ 0.48811422,  1.56761022,  1.47477764],
#        [-0.58368278,  0.89992259,  0.06406965],
#        [ 0.84537988, -0.92355114, -0.94357891],
#        [-0.94094845,  0.63809802,  0.83660022],
#        [ 0.48811422, -0.5868597 ,  1.40760107],
#        [-0.58368278, -0.12030148, -0.80922577],
#        [ 0.13084855, -0.07266619, -0.67487262]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error

def results(predictions):
  print("Mean absolute error on model is{}",format(mean_absolute_error(y_test,predictions)))
  print("Root maen squared error on model is{}",format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictionlr = lr.predict(X_test)

# %%
results(predictionlr)
# Out:
# Mean absolute error on model is{} 18048.817258946943
# Root maen squared error on model is{} 20928.395030639043

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

svrmodel = SVR()

# %%
param_gridsvr = {
    'C': [0.1, 1, 10],
    'kernel': ['linear','poly', 'rbf'],
    'degree':[2,3,4]
}

# %%
gridsvr = GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(X_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'kernel': 'linear'}

# %%
predictionssvr = gridsvr.predict(X_test)

# %%
results(predictionssvr)
# Out:
# Mean absolute error on model is{} 17980.515785878153
# Root maen squared error on model is{} 20834.168212861077

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()

param_gridrfr = {
    'n_estimators': [2,3,4,5,6,],
    'max_depth': [5,10,15],
}

# %%
gridrfr = GridSearchCV(estimator=rfmodel,param_grid=param_gridrfr,cv=5)

# %%
gridrfr.fit(X_train,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_

# %%
predictionofrfr = gridrfr.predict(X_test)
results(predictionofrfr)
# Out:
# Mean absolute error on model is{} 18241.187821565432
# Root maen squared error on model is{} 21220.194224363277

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr, 'model.pkl')
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
